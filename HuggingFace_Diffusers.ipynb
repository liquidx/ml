# %% [markdown]
# <a href="https://colab.research.google.com/github/liquidx/ml/blob/main/HuggingFace_Diffusers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Source: https://github.com/huggingface/diffusers
#
# This notebook runs the LDM model for text to image generation. Running this on Google Colab with V100 GPUs should take about 5s per image.
#
# Tip: Ensure your runtime is GPU (^^^ Runtime > Change Runtime Type > GPU).

# %%
# !pip install -q diffusers transformers
# Out:
#      |████████████████████████████████| 95 kB 4.1 MB/s
#      |████████████████████████████████| 4.7 MB 19.4 MB/s
#      |████████████████████████████████| 101 kB 13.0 MB/s
#      |████████████████████████████████| 6.6 MB 47.5 MB/s
#      |████████████████████████████████| 596 kB 54.0 MB/s

# %%
# %matplotlib inline
from diffusers import DiffusionPipeline
from matplotlib import pyplot as plt

# %%
# Load model (~4GB download)
model_id = "CompVis/ldm-text2im-large-256"
ldm = DiffusionPipeline.from_pretrained(model_id)
# Out:
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.96k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/118k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/108k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/98.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/80.8k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/376 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/252 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/420 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/713 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.49G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/522 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/335M [00:00<?, ?B/s]

# %%
# Edit this prompt and run (Shift + Enter)
prompt = "photo of shopfront of modern coffee shop"
images = ldm([prompt], num_inference_steps=50, eta=0.3, guidance_scale=6)["sample"]
plt.imshow(images[0])
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
