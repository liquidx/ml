# %% [markdown]
# <a href="https://colab.research.google.com/github/liquidx/ml/blob/main/Practice_HuggingFace_Transforms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Source: https://github.com/huggingface/diffusers

# %%
# !pip install diffusers transformers

# %%
# %matplotlib inline
from diffusers import DiffusionPipeline
from matplotlib import pyplot as plt

# %%
model_id = "CompVis/ldm-text2im-large-256"

# load model and scheduler
ldm = DiffusionPipeline.from_pretrained(model_id)

# %%
prompt = "photo of shopfront of modern coffee shop"
images = ldm([prompt], num_inference_steps=50, eta=0.3, guidance_scale=6)["sample"]
plt.imshow(images[0])
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
